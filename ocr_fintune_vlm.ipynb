# %% [markdown]
# <a href="https://colab.research.google.com/github/Dawy3/OCR-FineTune-vlm/blob/main/ocr_fintune_vlm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdf2image==1.17.0 pillow==12.1.0
# !apt-get install -y poppler-utils
# Out:
# Requirement already satisfied: pdf2image==1.17.0 in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Requirement already satisfied: pillow==12.1.0 in /usr/local/lib/python3.12/dist-packages (12.1.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 0s (2,793 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
from google.colab import drive
drive.mount("/gdrive")
# Out:
# Mounted at /gdrive

# %%
import os
from os.path import join
import random
from tqdm.auto import tqdm

from glob import glob                    # Scan the directory 'data_dir'
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance

data_dir = "/gdrive/MyDrive/Assets"

# %% [markdown]
# # PDF to Image

# %%
def preporcess_image(image, max_width=600):
  """
  Preprocess image to reduce size and prepare for OCR.

  Args:
    Image: PIL Image Object
    max_width: Maximum width in pixels (height auto-calculated to maintain ratio)

  steps:
  1. Convert to grayscale (reduce size and improve OCR)
  2. Resize to reasonable width while maintaining asepct ratio
  3. Increase contrast
  """
  # Convert ot grayscale
  gray_image = image.convert('L')

  # Resize if image is too large
  if gray_image.width > max_width:
      # Calculate new height to maintain aspect ration
      ratio = max_width / gray_image.width
      new_height = int(gray_image.height * ratio)
      gray_image = gray_image.resize((max_width, new_height), Image.LANCZOS)

  # Increaet contrast
  enhancer = ImageEnhance.Contrast(gray_image)
  enhanced_image = enhancer.enhance(1.5)

  return enhanced_image

def convert_pdf_to_images(pdf_path, output_base_dir, max_width=600):
    """
    Convert a PDF file to a set of preprocessed images.

    Args:
        pdf_path: Path to the PDF file
        output_base_dir: Base directory to save images
        max_width: Maximum width for output images (default: 600px)
    """
    # Get PDF filename without extension
    pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]

    # Create output directory for this PDF
    output_dir = join(output_base_dir, pdf_name)
    os.makedirs(output_dir, exist_ok=True)

    print(f"Convert {pdf_name}.pdf...")

    images = convert_from_path(pdf_path, dpi=200)
    generated_paths = []


    # Process and save each page
    for page_num, image in enumerate(images, start=1):

        # Preprocess the image
        processed_image = preporcess_image(image, max_width)

        # Save as JPEG with optimization
        # page_o11.jpg
        output_path = join(output_dir, f"page_{page_num:03d}.jpg")
        processed_image.save(output_path, 'JPEG', quality=85, optimize=True)

        print(f"  Saved page_{page_num:03d} in {output_path}")
        generated_paths.append(output_path)

    return generated_paths

# %%
output_dir = f"{data_dir}/pdf_images"
pdf_files = glob(f"{data_dir}/*.pdf")
max_width = 600

for pdf_file in tqdm(pdf_files):

    _ = convert_pdf_to_images(
          pdf_file,
          output_dir,
          max_width
      )
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Convert قواعد العمل.pdf...
#   Saved page_001 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_001.jpg
#   Saved page_002 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_002.jpg
#   Saved page_003 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_003.jpg
#   Saved page_004 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_004.jpg
#   Saved page_005 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_005.jpg
#   Saved page_006 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_006.jpg
#   Saved page_007 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_007.jpg
#   Saved page_008 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_008.jpg
#   Saved page_009 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_009.jpg
#   Saved page_010 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_010.jpg
#   Saved page_011 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_011.jpg
#   Saved page_012 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_012.jpg
#   Saved page_013 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_013.jpg
#   Saved page_014 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_014.jpg
#   Saved page_015 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_015.jpg
#   Saved page_016 in /gdrive/MyDrive/Assets/pdf_images/قواعد العمل/page_016.jpg
# Convert تعميم اداري للمحاسبين.pdf...
#   Saved page_001 in /gdrive/MyDrive/Assets/pdf_images/تعميم اداري للمحاسبين/page_001.jpg
#   Saved page_002 in /gdrive/MyDrive/Assets/pdf_images/تعميم اداري للمحاسبين/page_002.jpg
#   Saved page_003 in /gdrive/MyDrive/Assets/pdf_images/تعميم اداري للمحاسبين/page_003.jpg
#   Saved page_004 in /gdrive/MyDrive/Assets/pdf_images/تعميم اداري للمحاسبين/page_004.jpg
